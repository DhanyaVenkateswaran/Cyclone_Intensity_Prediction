# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# %%
tab_ds_atl=('tabulated_dataset/atlantic.csv')
df=pd.read_csv('tabulated_dataset/atlantic.csv')
df.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 0     94.8W            80              -999  ...         -999         -999
# 1     95.4W            80              -999  ...         -999         -999
# 2     96.0W            80              -999  ...         -999         -999
# 3     96.5W            80              -999  ...         -999         -999
# 4     96.8W            80              -999  ...         -999         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    High Wind NE  High Wind SE  High Wind SW  High Wind NW
# 0          -999          -999          -999          -999
# 1          -999          -999          -999          -999
# 2          -999          -999          -999          -999
# 3          -999          -999          -999          -999
# 4          -999          -999          -999          -999
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (49105, 22)

# %%
# df.drop(['Name'], axis=1)
mdf=df.drop(['Status','ID','Name'],axis=1)
lat=mdf['Latitude']
lon=mdf['Longitude']
event=mdf['Event']
for i in range(len(list(lat))):
    lat[i]=float(lat[i][:-1])
    lon[i]=float(lon[i][:-1])
    event[i]=ord(event[i][0])
mdf
# Out:
# C:\Users\melod\AppData\Local\Temp\ipykernel_18540\3866280240.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat[i]=float(lat[i][:-1])
# C:\Users\melod\AppData\Local\Temp\ipykernel_18540\3866280240.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lon[i]=float(lon[i][:-1])
# C:\Users\melod\AppData\Local\Temp\ipykernel_18540\3866280240.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   event[i]=ord(event[i][0])
#            Date  Time Event Latitude Longitude  Maximum Wind  \
# 0      18510625     0    32     28.0      94.8            80
# 1      18510625   600    32     28.0      95.4            80
# 2      18510625  1200    32     28.0      96.0            80
# 3      18510625  1800    32     28.1      96.5            80
# 4      18510625  2100    32     28.2      96.8            80
# ...         ...   ...   ...      ...       ...           ...
# 49100  20151112  1200    32     41.3      50.4            55
# 49101  20151112  1800    32     41.9      49.9            55
# 49102  20151113     0    32     41.5      49.2            50
# 49103  20151113   600    32     40.8      47.5            45
# 49104  20151113  1200    32     40.7      45.4            45
#
#        Minimum Pressure  Low Wind NE  Low Wind SE  Low Wind SW  Low Wind NW  \
# 0                  -999         -999         -999         -999         -999
# 1                  -999         -999         -999         -999         -999
# 2                  -999         -999         -999         -999         -999
# 3                  -999         -999         -999         -999         -999
# 4                  -999         -999         -999         -999         -999
# ...                 ...          ...          ...          ...          ...
# 49100               981          220          220          180          120
# 49101               983          220          220          180          120
# 49102               985          540          520          200          220
# 49103               985          620          460          180          220
# 49104               987          710          400          150          220
#


# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# %%
x_train
# Out:
#            Date  Time Event Latitude Longitude  Maximum Wind  \
# 20440  19441011  1200    32     35.5      40.0            40
# 48686  20141012   810    32     32.3      64.7            70
# 44573  20051129  1200    32     31.6      50.0            45
# 15537  19271102  1800    32     30.5      74.5            35
# 14101  19211122  1800    32     22.3      78.8            40
# ...         ...   ...   ...      ...       ...           ...
# 21243  19480827   600    32     24.7      65.4            80
# 45891  20081012   600    32     15.5      36.6            30
# 42613  20030716     0    32     28.5      98.2            50
# 43567  20040919  1800    32     16.7      43.4           110
# 2732   18750909   600    32     39.5      51.0            70
#
#        Minimum Pressure  Low Wind NE  Low Wind SE  Low Wind SW  Low Wind NW  \
# 20440              -999         -999         -999         -999         -999
# 48686               984          150          150          120          120
# 44573               993           45            0           90          120
# 15537              -999         -999         -999         -999         -999
# 14101              -999         -999         -999         -999         -999
# ...                 ...          ...          ...          ...          ...
# 21243              -999         -999         -999         -999         -999
# 45891              1007            0            0            0            0
# 42613               995         -999         -999         -999         -999
# 43567               951          150          105           90          105
# 2732               -999         -999         -999         -999         -999
#
#        Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# 20440              -999              -999              -999              -999
# 48686                50                60                60                60
# 44573                 0                 0                 0                 0
# 15537              -999              -999              -999              -999
# 14101              -999              -999              -999              -999
# ...                 ...               ...               ...               ...
# 21243              -999              -999              -999              -999
# 45891                 0                 0                 0                 0
# 42613              -999              -999              -999              -999
# 43567                50                40                40                50
# 2732               -999              -999              -999              -999
#
#        High Wind NE  High Wind SE  High Wind SW  High Wind NW
# 20440          -999          -999          -999          -999
# 48686             0            20            20             0
# 44573             0             0             0             0
# 15537          -999          -999          -999          -999
# 14101          -999          -999          -999          -999
# ...             ...           ...           ...           ...
# 21243          -999          -999          -999          -999
# 45891             0             0             0             0
# 42613          -999          -999          -999          -999
# 43567            35            25            25            35
# 2732           -999          -999          -999          -999
#
# [39284 rows x 19 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 10, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred = classifier.predict(x_test)
# Out:
# C:\Users\melod\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
y_test
# Out:
# 1561      HU
# 25729     TS
# 23043     TD
# 7529      HU
# 39231     TS
#         ...
# 42456     TS
# 20061     HU
# 43462     LO
# 21085     TS
# 16801     TS
# Name: Status, Length: 9821, dtype: object

# %%
y_pred
# Out:
# array([' HU', ' EX', ' TD', ..., ' LO', ' TS', ' TS'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test,y_pred)

# %%
cm
# Out:
# array([[   1,    0,    0,    4,    0,    0,    7,    3,    0],
#        [   0,  677,   38,   12,    1,    2,   73,  182,    0],
#        [   0,   39, 2781,    0,    0,    0,    0,   44,    0],
#        [   1,   10,    0,  104,    2,    1,   69,   11,    0],
#        [   0,    3,    0,    1,    6,    0,   52,    4,    0],
#        [   0,    7,   11,    1,    0,    6,    6,   77,    0],
#        [   1,   30,    0,   51,    5,    0, 1811,   75,    0],
#        [   0,  109,  104,    3,    1,   10,  150, 3213,    0],
#        [   0,    0,    0,    2,    0,    0,   17,    3,    0]],
#       dtype=int64)

# %%
ac
# Out:
# 0.8755727522655534

# %%
# Out:
# array([' HU', ' EX', ' TD', ..., ' LO', ' TS', ' TS'], dtype=object)
